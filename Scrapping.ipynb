# %%
# !pip3 install snscrape

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
from datetime import timedelta, datetime
t_data = pd.DataFrame(columns=['date', 'id','url', 'tweet_content', 'user','reply_count', 'retweet_count','language', 'source', 'like_count'])
search_key_word = 'LIC'

since = (datetime.now() - timedelta(days=100)).strftime("%Y-%m-%d")
until = datetime.now().strftime("%Y-%m-%d")

search_input = str(search_key_word) + ' since:' +str(since)+ ' until:' + str(until)

for i,tweet in enumerate(sntwitter.TwitterSearchScraper(search_input).get_items()):
    if i>1000:
        break
    t_data=t_data.append({'date':tweet.date,
      'id':tweet.id,
      'url':tweet.url,
      'tweet_content':tweet.content,
      'user':tweet.user,
      'reply_count':tweet.replyCount,
      'retweet_count':tweet.retweetCount,
      'language':tweet.lang,
      'source':tweet.source,
      'like_count':tweet.likeCount}, ignore_index=True)
# Out:
# <ipython-input-21-7202fbed8b6a>:18: FutureWarning: content is deprecated, use rawContent instead
#   'tweet_content':tweet.content,

# %%
t_data
# Out:
#                           date                   id  \
# 0    2023-01-24 23:59:24+00:00  1618035771784720385
# 1    2023-01-24 23:58:58+00:00  1618035662598590465
# 2    2023-01-24 23:58:28+00:00  1618035538002599936
# 3    2023-01-24 23:58:09+00:00  1618035457648123906
# 4    2023-01-24 23:57:58+00:00  1618035410663538688
# ...                        ...                  ...
# 996  2023-01-24 17:37:48+00:00  1617939738106945536
# 997  2023-01-24 17:37:21+00:00  1617939625867382784
# 998  2023-01-24 17:37:09+00:00  1617939575955156993
# 999  2023-01-24 17:36:59+00:00  1617939536344141826
# 1000 2023-01-24 17:36:04+00:00  1617939305678393346
#
#                                                     url  \
# 0     https://twitter.com/AtzaGuerra/status/16180357...
# 1     https://twitter.com/Gabriieel_04/status/161803...
# 2     https://twitter.com/lainajkajbon/status/161803...
# 3     https://twitter.com/pulsosurmx/status/16180354...
# ...

# %%
import pymongo
from pymongo import MongoClient
# Connect to MongoDB and create a new collection called 'tweets_give'
client = pymongo.MongoClient("mongodb://localhost:27017")
client.list_database_names()
db = client['guvi']
collection = db['tweets_guvi']

print(collection)

one_record = collection.find_one()
one_record
# Convert the pandas dataframe to a dictionary
data_dict = t_data.to_dict(orient='records')
db.tweets_guvi.insert_many(data_dict)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-46-b474e75f7014> in <module>
#       3 # Connect to MongoDB and create a new collection called 'tweets_give'
#       4 client = pymongo.MongoClient("mongodb://localhost:27017")
# ----> 5 client.list_database_names()
#       6 # db = client['guvi']
#       7 # collection = db['tweets_guvi']
#
# /usr/local/lib/python3.8/dist-packages/pymongo/mongo_client.py in list_database_names(self, session, comment)
#    1865         .. versionadded:: 3.6
#    1866         """
# -> 1867         return [doc["name"] for doc in self.list_databases(session, nameOnly=True, comment=comment)]
#    1868
#    1869     @_csot.apply
#
# /usr/local/lib/python3.8/dist-packages/pymongo/mongo_client.py in list_databases(self, session, comment, **kwargs)
#    1838             cmd["comment"] = comment
# ...
